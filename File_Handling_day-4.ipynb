# %%
f = open('abc.txt','w')
print('File name : ',f.name)
print('File mode : ',f.mode)
print(f.readable())
print(f.writable())
print(f.closed)
f.close()
print(f.closed)
# Out:
# File name :  abc.txt
# File mode :  w
# False
# True
# False
# True

# %%
with open("abc.txt","r") as file:
    content = file.read()
    print(content)
# Out:
# Aditya Degree College
# Kakinada
# Andhra Pradesh

# %%
with open("abc.txt","r") as file:
    content = file.read(10)
    print(content)
# Out:
# Aditya Deg

# %%
with open("abc.txt","r") as file:
    content = file.readline()
    print(content)
# Out:
# Aditya Degree College

# %%
with open("abc.txt","r") as file:
    content = file.readlines()
    print(content)
# Out:
# ['Aditya Degree College\n', 'Kakinada\n', 'Andhra Pradesh\n']

# %%
with open("abc.txt","w") as file:
    file.write("Aditya Degree College")

# %%
l=["Aditya Degree College\n","Kakinada\n","Andhra Pradesh\n"]
with open("abc.txt","w") as file:
    file.writelines(l)

# %%
with open("abc.txt","a") as file:
    file.write("533001")

# %%
#writing to a csv file
import csv
with open("data.csv","w",newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["Name","Age","City"])
    writer.writerow(["Raju","22","Bangalore"])
    writer.writerow(["Vamsi","25","Hydrabad"])

# %%
import csv
with open("data.csv","r") as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['Name', 'Age', 'City']
# ['Raju', '22', 'Bangalore']
# ['Vamsi', '25', 'Hydrabad']
