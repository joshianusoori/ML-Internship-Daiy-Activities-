# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
data= pd.DataFrame({
"age":[18,22,25,30,35,40,45,50]})
print(data)
# Out:
#    age
# 0   18
# 1   22
# 2   25
# 3   30
# 4   35
# 5   40
# 6   45
# 7   50

# %% [markdown]
# #Equal-Width

# %%
data[ "age_bin"] = pd. cut(data[ "age"], bins=4)
data
# Out:
#    age         age_bin
# 0   18  (17.968, 26.0]
# 1   22  (17.968, 26.0]
# 2   25  (17.968, 26.0]
# 3   30    (26.0, 34.0]
# 4   35    (34.0, 42.0]
# 5   40    (34.0, 42.0]
# 6   45    (42.0, 50.0]
# 7   50    (42.0, 50.0]

# %%
plt.hist(data[ "age"], bins=4)
plt.xlabel("age")
plt.ylabel( "frequency")
plt.title("Equal-Width Binning using pd. cut() ")
plt. show()

# %%
plt.hist(data[ "age"], bins=3)
plt.xlabel("age")
plt.ylabel( "frequency")
plt.title("Equal-Width Binning using pd. cut() ")
plt. show()

# %% [markdown]
# # Equal frequency binning(quantile binning)

# %%
data2["age_frequency_bin"] = pd.qcut(data[ "age"], q=4)
data2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 data2["age_frequency_bin"] = pd.qcut(data[ "age"], q=4)
#       2 data2
#
# NameError: name 'data2' is not defined
